# %% [markdown]
# # Numpy Arrays

# %%
# 1d array
import numpy as np 

list1 = [1,1.1,-5.45,3.2]
arr1 = np.array(list1)
arr1
# Out:
# array([ 1.  ,  1.1 , -5.45,  3.2 ])

# %%
# 2d array
list2 = [[1,1.1,-5.45,3.2],[-0.5,0.33,10.12,-5]]
arr2 = np.array(list2)
arr2
# Out:
# array([[ 1.  ,  1.1 , -5.45,  3.2 ],
#        [-0.5 ,  0.33, 10.12, -5.  ]])

# %%
arr1.shape
# Out:
# (4,)

# %%
arr2.shape
# Out:
# (2, 4)

# %% [markdown]
# # Basic Operations
# - Operations between equal-size arrays or arrays and scalars operate element-wise
# - Boolean operations on arrays also act element-wise
# - No loops needed

# %%
# 02_numpy makes array - scalar operations easier
list1-5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # numpy makes array - scalar operations easier
# ----> 2 list1-5
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'

# %%
# using lists: very clunky loop
new_list1=[]
for x in list1:
    new_list1.append(x-5)
print (new_list1)
# Out:
# [-4, -3.9, -10.45, -1.7999999999999998]

# %%
list1
# Out:
# [1, 1.1, -5.45, 3.2]

# %%
arr1 - 5
# Out:
# array([ -4.  ,  -3.9 , -10.45,  -1.8 ])

# %%
# 02_numpy makes array - array operations easier
list2*list2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # numpy makes array - array operations easier
# ----> 2 list2*list2
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
arr2*arr2
# Out:
# array([[  1.    ,   1.21  ,  29.7025,  10.24  ],
#        [  0.25  ,   0.1089, 102.4144,  25.    ]])

# %%
arr2
# Out:
# array([[ 1.  ,  1.1 , -5.45,  3.2 ],
#        [-0.5 ,  0.33, 10.12, -5.  ]])

# %%
# 02_numpy makes array - scalar boolean logic easier
list1 > 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # numpy makes array - scalar boolean logic easier
# ----> 2 list1 > 0
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
# using lists: very clunky loop
is_pos=[]
for x in list1:
    is_pos.append(x>0)
is_pos
# Out:
# [True, True, False, True]

# %%
arr1 > 0
# Out:
# array([ True,  True, False,  True])

# %%
# 02_numpy makes array - array boolean logic easier
arr1 = np.array([1,2,3,4])
arr2 = np.array([0,3,5,6])
arr1 > arr2
# Out:
# array([ True, False, False, False])

# %%
# 02_numpy makes logical operations on boolean arrays easier
bool1 = (arr1 > 0) 
bool1
# Out:
# array([ True,  True,  True,  True])

# %%
bool2 = (arr1 > 1)
bool2
# Out:
# array([False,  True,  True,  True])

# %%
bool1 & bool2
# Out:
# array([False,  True,  True,  True])

# %%
bool1 | bool2
# Out:
# array([ True,  True,  True,  True])
