# %% [markdown]
# # Array Indexing
# 1. Integer Indexing
# 2. Boolean Indexing
#
# ## Integer Indexing

# %%
# Initialize variables

import numpy as np 

list1 = [1,1.1,-5.45,3.2]
arr1 = np.array(list1)

list2 = [[1,1.1,-5.45,3.2],[-0.5,0.33,10.12,-5]]
arr2 = np.array(list2)

# %%
# 1d arrays are similar to 01_python lists
print (arr1[0])
print (arr1[1:3])
print (arr1[-2:])
# Out:
# 1.0
# [ 1.1  -5.45]
# [-5.45  3.2 ]

# %%
# 2d array indexing
arr2
# Out:
# array([[ 1.  ,  1.1 , -5.45,  3.2 ],
#        [-0.5 ,  0.33, 10.12, -5.  ]])

# %%
arr2[0]
# Out:
# array([ 1.  ,  1.1 , -5.45,  3.2 ])

# %%
arr2[0][1]
# Out:
# np.float64(1.1)

# %%
arr2[0,1]
# Out:
# np.float64(1.1)

# %%
arr2[0,:3]
# Out:
# array([ 1.  ,  1.1 , -5.45])

# %%
arr2[:,:3]
# Out:
# array([[ 1.  ,  1.1 , -5.45],
#        [-0.5 ,  0.33, 10.12]])

# %%
list2[:,:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 list2[:,:3]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
arr2[:,[1,3,-1]]
# Out:
# array([[ 1.1 ,  3.2 ,  3.2 ],
#        [ 0.33, -5.  , -5.  ]])

# %% [markdown]
# ## Boolean Indexing

# %%
mask=arr1>0
mask
# Out:
# array([ True,  True, False,  True])

# %%
arr1[mask]
# Out:
# array([1. , 1.1, 3.2])

# %%
arr2[[True,False],:2]
# Out:
# array([[1. , 1.1]])

# %%
arr2
# Out:
# array([[ 1.  ,  1.1 , -5.45,  3.2 ],
#        [-0.5 ,  0.33, 10.12, -5.  ]])

# %%
mask = arr2 < 0
mask
# Out:
# array([[False, False,  True, False],
#        [ True, False, False,  True]])

# %%
arr2[mask]
# Out:
# array([-5.45, -0.5 , -5.  ])

# %%
arr2[mask]=0
arr2
# Out:
# array([[ 1.  ,  1.1 ,  0.  ,  3.2 ],
#        [ 0.  ,  0.33, 10.12,  0.  ]])
