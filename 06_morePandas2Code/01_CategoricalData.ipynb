# %% [markdown]
# # Categorical Data: Unique Values, Membership, Dummies

# %%
import pandas as pd 
ser = pd.Series({'AAPL':'Tech','XOM':'Energy','MSFT':'Tech','LULU':'Consumer','TSLA':'Consumer','GS':'Financials',
                'BAC':'Financials'})
ser
# Out:
# AAPL          Tech
# XOM         Energy
# MSFT          Tech
# LULU      Consumer
# TSLA      Consumer
# GS      Financials
# BAC     Financials
# dtype: object

# %%
# Get Unique values
ser.unique()
# Out:
# array(['Tech', 'Energy', 'Consumer', 'Financials'], dtype=object)

# %%
# Get Unique Values & Counts
ser.value_counts()
# Out:
# Tech          2
# Consumer      2
# Financials    2
# Energy        1
# Name: count, dtype: int64

# %%
mask=ser.isin(['Financials','Tech'])
mask
# Out:
# AAPL     True
# XOM     False
# MSFT     True
# LULU    False
# TSLA    False
# GS       True
# BAC      True
# dtype: bool

# %%
ser[mask]
# Out:
# AAPL          Tech
# MSFT          Tech
# GS      Financials
# BAC     Financials
# dtype: object

# %%
pd.get_dummies(ser)
# Out:
#       Consumer  Energy  Financials   Tech
# AAPL     False   False       False   True
# XOM      False    True       False  False
# MSFT     False   False       False   True
# LULU      True   False       False  False
# TSLA      True   False       False  False
# GS       False   False        True  False
# BAC      False   False        True  False

# %%
# if the mask needs numeric indicators, add dtype=int

pd.get_dummies(ser, dtype=int)
# Out:
#       Consumer  Energy  Financials  Tech
# AAPL         0       0           0     1
# XOM          0       1           0     0
# MSFT         0       0           0     1
# LULU         1       0           0     0
# TSLA         1       0           0     0
# GS           0       0           1     0
# BAC          0       0           1     0
