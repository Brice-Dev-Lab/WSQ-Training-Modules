# %% [markdown]
# # Groupby, Pivot, Merge

# %%
import pandas as pd 
import numpy as np 

univ = ['AAPL','MSFT','BAC','GS']
dates = pd.date_range('20110101','20201231')
df = pd.DataFrame(np.random.randn(len(dates),len(univ)),index=dates,columns=univ)
df
# Out:
#                 AAPL      MSFT       BAC        GS
# 2011-01-01 -0.943897  0.373983  0.598350 -0.192172
# 2011-01-02  0.537674  0.797509 -1.056027 -0.210019
# 2011-01-03  0.278795 -1.240424 -1.185791 -0.097160
# 2011-01-04  0.096625  0.904387  0.570216  0.171147
# 2011-01-05  0.969495  0.586740 -1.482477 -0.848472
# ...              ...       ...       ...       ...
# 2020-12-27 -1.113192  0.423943  0.219241 -1.131165
# 2020-12-28 -0.530481  1.057799 -1.168232 -2.302132
# 2020-12-29 -0.031129  0.389927  0.069369  1.793588
# 2020-12-30  2.794049 -0.785922 -1.045634  0.696199
# 2020-12-31  0.835697  1.347003  0.330095  1.606246
#
# [3653 rows x 4 columns]

# %%
sector = {'AAPL':'Tech','MSFT':'Tech','BAC':'Fin','GS':'Fin'}
data=[]
for dt in dates:
    for x in univ:
        data.append([x,sector[x],dt,np.random.randn(),np.random.randn()])
data = pd.DataFrame(data,columns=['ticker','sector','date','signal1','signal2'])
data
# Out:
#       ticker sector       date   signal1   signal2
# 0       AAPL   Tech 2011-01-01 -0.793342  2.153621
# 1       MSFT   Tech 2011-01-01 -1.324149  0.118347
# 2        BAC    Fin 2011-01-01 -2.079259  0.526904
# 3         GS    Fin 2011-01-01 -0.836656 -0.709944
# 4       AAPL   Tech 2011-01-02 -0.729122  0.742958
# ...      ...    ...        ...       ...       ...
# 14607     GS    Fin 2020-12-30  1.422918 -0.075406
# 14608   AAPL   Tech 2020-12-31 -0.417542 -0.370151
# 14609   MSFT   Tech 2020-12-31  0.775558 -1.715211
# 14610    BAC    Fin 2020-12-31  1.244797 -0.107636
# 14611     GS    Fin 2020-12-31 -0.351531  0.181699
#
# [14612 rows x 5 columns]

# %% [markdown]
# ## Groupby

# %%
# whats the average signal of each ticker?
data.groupby(['ticker', 'signal1', 'signal2']).mean(numeric_only=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(AAPL, -3.7748864147811103, 0.8596170629374236), (AAPL, -3.370865994412908, -0.3811807287170846), (AAPL, -3.260199438161255, -1.7445237589082212), (AAPL, -3.1808366277755353, -1.0858624331838227), (AAPL, -3.086007454201185, 0.8369950100325356), (AAPL, -3.003136935732004, 1.5334650021624765), (AAPL, -2.992049117311347, 1.0398736062139495), (AAPL, -2.895457526548605, 0.6846335004881123), (AAPL, -2.8725867978695163, -1.3505289323340697), (AAPL, -2.84781623267123, -0.8125165115592194), (AAPL, -2.788877943551728, -1.903212164407175), (AAPL, -2.7465644667085867, 0.21100510287991348), (AAPL, -2.738431500868387, 0.9719192723289298), (AAPL, -2.7381518268929437, -0.38755666254138094), (AAPL, -2.6962869336632496, -1.221639601588256), (AAPL, -2.685489165693108, -0.5974002859737807), (AAPL, -2.6438878338383947, -1.3486039103991292), (AAPL, -2.6372648187793937, -0.4040610646784336), (AAPL, -2.59649632965152, 0.2643558348679345), (AAPL, -2.587973658614073, -0.162350417869965), (AAPL, -2.576688047957324, 0.4778031364317436), (AAPL, -2.545362758455743, 0.4134696944252811), (AAPL, -2.533531954034562, 0.7047900332339435), (AAPL, -2.5320900546291005, 1.7250077448767183), (AAPL, -2.5246918545332155, -0.10636678131096383), (AAPL, -2.516963452145208, -0.43776103869520516), (AAPL, -2.503071285850583, 1.3758085853857196), (AAPL, -2.4741536275164036, -0.6329497261895305), (AAPL, -2.4656823497185645, -0.9765586901224561), (AAPL, -2.431275760503192, -1.01104119661081), (AAPL, -2.4297531318203167, 0.25614295659488345), (AAPL, -2.4117458149948443, 0.47567290436187276), (AAPL, -2.4040820287290696, -1.7724263635936104), (AAPL, -2.3864208873751833, -1.0565237974191324), (AAPL, -2.3697063855149394, 0.7966493158437331), (AAPL, -2.3640486542147325, 1.2875251368400735), (AAPL, -2.3517555640317376, -0.45409025836015177), (AAPL, -2.3398986426097155, 0.542543632504549), (AAPL, -2.330698300839848, -0.768513132961581), (AAPL, -2.319549219268509, -0.3947401586888729), (AAPL, -2.3150742053120124, 0.22960875217939375), (AAPL, -2.310584512402413, 0.14112022434485136), (AAPL, -2.3095937409351137, 0.7286801196437379), (AAPL, -2.3059149582133895, 0.11953774264228069), (AAPL, -2.2918991135470397, 0.9630278053002997), (AAPL, -2.2898385361325295, 0.3173144368924661), (AAPL, -2.2840593394732065, -0.41095592370429834), (AAPL, -2.2720598588940164, 1.1164739800101215), (AAPL, -2.268465384701168, 0.732641369066269), (AAPL, -2.2664534256861173, 0.9793355835416148), (AAPL, -2.254499160891623, -1.6786326543315384), (AAPL, -2.2387073146923537, -0.13689207719931287), (AAPL, -2.236414878527513, -1.5235316066878044), (AAPL, -2.2327688948995625, 1.7899198512816115), (AAPL, -2.1900146465549213, 0.08672658935685985), (AAPL, -2.1818845036228924, 0.7398348101648033), (AAPL, -2.1724915119432517, 0.871060459382909), (AAPL, -2.1682542892532535, -0.6584056033199234), (AAPL, -2.1586231088686607, -0.4764136565838513), (AAPL, -2.155403763164434, 0.7685610017749082), (AAPL, -2.153358514065378, -0.438806248752312), (AAPL, -2.1482422188936767, -1.006161017607875), (AAPL, -2.141259517484376, -1.4235161624185677), (AAPL, -2.1397742261936243, 2.028437197416336), (AAPL, -2.1392383054759025, 2.020553218491331), (AAPL, -2.1389496826033136, 0.9872813205663722), (AAPL, -2.1354431030307395, -0.6516557451934839), (AAPL, -2.1306121842609547, -1.0145414973779645), (AAPL, -2.128518006265034, -1.1439088640275288), (AAPL, -2.128427249178292, 0.6070312977678144), (AAPL, -2.102103644197242, -0.5132109575948801), (AAPL, -2.101148696887965, -0.8736266309850276), (AAPL, -2.0945648933803103, -0.020095172103573113), (AAPL, -2.0903313088143327, -1.6099640756573788), (AAPL, -2.0877918879077835, 1.918802403874838), (AAPL, -2.0860118078985295, 1.5284881597435371), (AAPL, -2.076642884778361, 0.8246692482149692), (AAPL, -2.0751673790209675, -1.0862704419420268), (AAPL, -2.063113426564276, -2.049915137770705), (AAPL, -2.061639298883165, -0.7372928410937992), (AAPL, -2.0487356808336257, -2.2029587180197465), (AAPL, -2.0484340 ...
#
# [14612 rows x 0 columns]

# %%
# whats the average signal of each sector on each day?
data.groupby(['sector','date']).mean(numeric_only=True)
# Out:
#                     signal1   signal2
# sector date
# Fin    2011-01-01 -1.457958 -0.091520
#        2011-01-02  0.545962 -0.203311
#        2011-01-03 -0.219207  1.030981
#        2011-01-04 -0.750572 -0.270143
#        2011-01-05 -0.751412  0.305335
# ...                     ...       ...
# Tech   2020-12-27 -0.978525 -0.248427
#        2020-12-28 -0.773858  0.282734
#        2020-12-29 -0.335429 -0.364546
#        2020-12-30  1.228489  0.390425
#        2020-12-31  0.179008 -1.042681
#
# [7306 rows x 2 columns]

# %%
# can index before applying the function
data.groupby(['sector','date'])[['signal1']].mean(numeric_only=True)
# Out:
#                     signal1
# sector date
# Fin    2011-01-01 -1.457958
#        2011-01-02  0.545962
#        2011-01-03 -0.219207
#        2011-01-04 -0.750572
#        2011-01-05 -0.751412
# ...                     ...
# Tech   2020-12-27 -0.978525
#        2020-12-28 -0.773858
#        2020-12-29 -0.335429
#        2020-12-30  1.228489
#        2020-12-31  0.179008
#
# [7306 rows x 1 columns]

# %% [markdown]
# # Pandas `.apply()` with `groupby`: Conceptual Summary
#
# ## 🧠 Core Idea
#
# `.apply()` lets you run a **custom function** on each group in a `groupby` operation.
#
# Unlike built-in methods (`mean`, `sum`, etc.), it gives you full control over the logic.
#
# ---
#
# ## 🔧 Example
#
#     def max_minus_min(x):
#         return x.max() - x.min()
#
#     data.groupby(['sector','date'])[['signal1','signal2']].apply(max_minus_min)
#
# ---
#
# ## 🧠 What’s Happening
#
# 1. Data is split into groups based on:
#
#        ('sector', 'date')
#
# 2. For each group:
#
#        x = subset of the DataFrame
#
# 3. Your function runs on each group:
#
#        x.max() - x.min()
#
# 4. Results are combined into a new DataFrame
#
# ---
#
# ## ⚡ When to Use `.apply()`
#
# Use `.apply()` when:
#
# - You need **custom logic** not available in built-in functions
# - You want to operate on **entire groups**, not just columns
# - You need flexibility beyond `.agg()` or `.transform()`
#
# ---
#
# ## ⚠️ Important Considerations
#
# - Slower than built-in aggregations (`mean`, `sum`, etc.)
# - Should not be your first choice if a built-in method exists
# - Best used for **non-standard or complex operations**
#
# ---
#
# ## 🧭 Mental Model
#
# Think of `groupby().apply()` as:
#
# > "Split → Apply custom function → Combine results"
#
# ---
#
# ## 🔑 Key Insight
#
# - `.agg()` → predefined, optimized operations
# - `.transform()` → returns same shape as input
# - `.apply()` → **maximum flexibility**, less performance
#
# ---
#
# ## 💡 Final Takeaway
#
# `.apply()` is the “escape hatch” for group operations:
#
# > Use it when Pandas doesn’t already give you the function you need

# %%
# use apply with groupby to pass an arbitrary function
def max_minus_min(x):
    return x.max()-x.min()

data.groupby(['sector','date'])[['signal1','signal2']].apply(max_minus_min
# Out:
#                     signal1   signal2
# sector date
# Fin    2011-01-01  0.585128  0.375484
#        2011-01-02  0.848111  1.734540
#        2011-01-03  1.923406  1.777767
#        2011-01-04  2.088586  0.170600
#        2011-01-05  0.442993  0.874202
# ...                     ...       ...
# Tech   2020-12-27  1.060827  2.462820
#        2020-12-28  0.941712  0.119097
#        2020-12-29  0.735819  0.223701
#        2020-12-30  1.473004  3.594782
#        2020-12-31  0.000740  1.111665
#
# [7306 rows x 2 columns]

# %%
# return a dataframe instead of a series
# the [[ 'text' ]] returns a dataframe
# the [ 'text' ] returns a series
def demean(x):
    return x - x.mean()

data.groupby(['sector','date'])[['signal1','signal2']].apply(demean)
# Out:
#                           signal1   signal2
# sector date
# Fin    2011-01-01 2      0.292564  0.187742
#                   3     -0.292564 -0.187742
#        2011-01-02 6      0.424055  0.867270
#                   7     -0.424055 -0.867270
#        2011-01-03 10    -0.961703 -0.888883
# ...                           ...       ...
# Tech   2020-12-29 14601 -0.367909 -0.111851
#        2020-12-30 14604  0.736502  1.797391
#                   14605 -0.736502 -1.797391
#        2020-12-31 14608 -0.000370  0.555833
#                   14609  0.000370 -0.555833
#
# [14612 rows x 2 columns]

# %%
df = data.groupby(['sector','date'])[['signal1','signal2']].mean()
df
# Out:
#                     signal1   signal2
# sector date
# Fin    2011-01-01 -0.203187 -0.065324
#        2011-01-02 -1.006247  1.047700
#        2011-01-03  1.052026  0.588958
#        2011-01-04 -0.448476 -0.334251
#        2011-01-05 -1.251335  0.432628
# ...                     ...       ...
# Tech   2020-12-27 -0.709643  0.275530
#        2020-12-28  0.244018  0.534283
#        2020-12-29  0.005680  0.482225
#        2020-12-30 -0.742111  0.633299
#        2020-12-31 -0.483540 -1.213430
#
# [7306 rows x 2 columns]

# %%
df.groupby(level=0).mean()
# Out:
#                 AAPL      MSFT       BAC        GS
# 2011-01-01  1.520429  1.447135 -0.157266  0.978755
# 2011-01-02 -0.240267  1.479742 -0.537518 -0.112783
# 2011-01-03  0.459333  0.107961 -0.211853  0.543682
# 2011-01-04  0.214619  1.011449  1.950263  0.874949
# 2011-01-05  0.202895  0.086989 -0.264394 -0.239951
# ...              ...       ...       ...       ...
# 2020-12-27  0.457880 -1.242520 -0.874413  1.545443
# 2020-12-28 -0.070364 -0.156876 -0.402209 -2.242678
# 2020-12-29 -0.192440 -0.179836 -0.006434 -0.289394
# 2020-12-30 -2.089112 -0.559439  0.767413  1.112193
# 2020-12-31  0.698724  0.673288  1.085240 -2.173544
#
# [3653 rows x 4 columns]

# %%
month = [x.month for x in data['date']]

# %%
data.groupby(month).mean(numeric_only=True)
# Out:
#      signal1   signal2
# 1   0.020137  0.021865
# 2  -0.031687 -0.041926
# 3   0.078626 -0.029075
# 4   0.002202  0.030336
# 5   0.002809 -0.033942
# 6  -0.000734 -0.020602
# 7  -0.015942  0.052253
# 8  -0.000860  0.013902
# 9  -0.017796  0.052094
# 10 -0.005868  0.012324
# 11  0.002628 -0.020182
# 12 -0.014361 -0.035675

# %%
for key,val in data.groupby('sector'):
    print (key)
# Out:
# Fin
# Tech

# %%
# iterating in a groupby
for key,val in data.groupby('sector'):
    print (val)
# Out:
#       ticker sector       date   signal1   signal2
# 2        BAC    Fin 2011-01-01  1.009180  1.956001
# 3         GS    Fin 2011-01-01  0.424052  1.580517
# 6        BAC    Fin 2011-01-02 -1.466306  0.758415
# 7         GS    Fin 2011-01-02 -2.314417 -0.976125
# 10       BAC    Fin 2011-01-03 -0.748832 -0.472427
# ...      ...    ...        ...       ...       ...
# 14603     GS    Fin 2020-12-29 -0.742333  0.747767
# 14606    BAC    Fin 2020-12-30 -0.104745  0.656342
# 14607     GS    Fin 2020-12-30  0.174601 -0.541720
# 14610    BAC    Fin 2020-12-31 -0.211526 -2.135673
# 14611     GS    Fin 2020-12-31 -0.109001 -0.065435
#
# [7306 rows x 5 columns]
#       ticker sector       date   signal1   signal2
# 0       AAPL   Tech 2011-01-01  0.283229  3.056726
# 1       MSFT   Tech 2011-01-01  0.144383  0.326354
# 4       AAPL   Tech 2011-01-02  0.035900  1.173141
# 5       MSFT   Tech 2011-01-02  1.079511  0.377148
# 8       AAPL   Tech 2011-01-03  1.745756 -1.341330
# ...      ...    ...        ...       ...       ...
# 14601   MSFT   Tech 2020-12-29 -0.091659 -0.444512
# 14604   AAPL   Tech 2020-12-30  1.390706  1.972789
# 14605   MSFT   Tech 2020-12-30 -0.082298 -1.621993
# 14608   AAPL   Tech 2020-12-31 -0.679130  0.258643
# 14609   MSFT   Tech 2020-12-31 -0.678390 -0.853023
#
# [7306 rows x 5 columns]

# %% [markdown]
# ## Pivot

# %%
data
# Out:
#       ticker sector       date   signal1   signal2
# 0       AAPL   Tech 2011-01-01  0.283229  3.056726
# 1       MSFT   Tech 2011-01-01  0.144383  0.326354
# 2        BAC    Fin 2011-01-01  1.009180  1.956001
# 3         GS    Fin 2011-01-01  0.424052  1.580517
# 4       AAPL   Tech 2011-01-02  0.035900  1.173141
# ...      ...    ...        ...       ...       ...
# 14607     GS    Fin 2020-12-30  0.174601 -0.541720
# 14608   AAPL   Tech 2020-12-31 -0.679130  0.258643
# 14609   MSFT   Tech 2020-12-31 -0.678390 -0.853023
# 14610    BAC    Fin 2020-12-31 -0.211526 -2.135673
# 14611     GS    Fin 2020-12-31 -0.109001 -0.065435
#
# [14612 rows x 5 columns]

# %%
# put Signal1 into a df with columns tickers and rows dates
df1 = data.set_index(['date','ticker'])['signal1'].unstack(level=1)
df1
# Out:
# ticker          AAPL       BAC        GS      MSFT
# date
# 2011-01-01  0.283229  1.009180  0.424052  0.144383
# 2011-01-02  0.035900 -1.466306 -2.314417  1.079511
# 2011-01-03  1.745756 -0.748832  1.174574  0.361653
# 2011-01-04 -0.830788  0.261571 -1.827015 -0.316657
# 2011-01-05 -1.551993  0.450485  0.893478 -0.285942
# ...              ...       ...       ...       ...
# 2020-12-27 -0.329149 -0.985159 -0.240506 -1.389977
# 2020-12-28 -0.454955  1.879978 -0.260495  0.486757
# 2020-12-29  0.644160 -0.957661 -0.742333 -0.091659
# 2020-12-30  1.390706 -0.104745  0.174601 -0.082298
# 2020-12-31 -0.679130 -0.211526 -0.109001 -0.678390
#
# [3653 rows x 4 columns]

# %%
df2 = data.pivot_table(index='date',columns='ticker',values='signal1')
df2
# Out:
# ticker          AAPL       BAC        GS      MSFT
# date
# 2011-01-01  0.283229  1.009180  0.424052  0.144383
# 2011-01-02  0.035900 -1.466306 -2.314417  1.079511
# 2011-01-03  1.745756 -0.748832  1.174574  0.361653
# 2011-01-04 -0.830788  0.261571 -1.827015 -0.316657
# 2011-01-05 -1.551993  0.450485  0.893478 -0.285942
# ...              ...       ...       ...       ...
# 2020-12-27 -0.329149 -0.985159 -0.240506 -1.389977
# 2020-12-28 -0.454955  1.879978 -0.260495  0.486757
# 2020-12-29  0.644160 -0.957661 -0.742333 -0.091659
# 2020-12-30  1.390706 -0.104745  0.174601 -0.082298
# 2020-12-31 -0.679130 -0.211526 -0.109001 -0.678390
#
# [3653 rows x 4 columns]

# %%
df1.equals(df2)
# Out:
# True

# %% [markdown]
# # Pandas `pivot_table`: Conceptual Summary
#
# ## 🧠 Core Idea
#
# `pivot_table` reshapes data from **long format → wide format**, while optionally aggregating duplicate values.
#
# ---
#
# ## 🔧 Example
#
#     data.pivot_table(
#         index='date',
#         columns='sector',
#         values='signal1',
#         aggfunc='mean'
#     )
#
# ---
#
# ## 🧠 What It Does
#
# - Rows (`index`) → unique dates
# - Columns (`columns`) → unique sectors
# - Values (`values`) → aggregated `signal1` values
# - Aggregation (`aggfunc`) → how duplicates are combined
#
# ---
#
# ## 🔄 Before (Long Format)
#
# | date       | sector | signal1 |
# |------------|--------|---------|
# | 2021-01-01 | Tech   | 0.5     |
# | 2021-01-01 | Tech   | 0.7     |
# | 2021-01-01 | Energy | 0.2     |
#
# ---
#
# ## 🔁 After (Wide Format)
#
# | date       | Tech | Energy |
# |------------|------|--------|
# | 2021-01-01 | 0.6  | 0.2    |
#
# ---
#
# ## ⚡ When to Use
#
# Use `pivot_table` when:
#
# - You need to **reshape raw data into a matrix**
# - You want to **compare categories side-by-side**
# - You have **duplicate combinations** and need aggregation
# - You are preparing data for **analysis or modeling**
#
# ---
#
# ## 🔑 Key Insight
#
# > Pivot transforms “rows of events” into a structured grid of values.
#
# ---
#
# ## 🧭 Mental Model
#
# - Long format → messy, row-based
# - Wide format → structured, column-based
#
# `pivot_table` is the bridge between the two.
#
# ---
#
# ## ⚠️ Note
#
# If no duplicates exist, you can use:
#
#     data.pivot(...)
#
# If duplicates exist, use:
#
#     data.pivot_table(...)
#
# ---
#
# ## 💡 Final Takeaway
#
# `pivot_table` makes your data:
#
# - easier to read
# - easier to compare
# - ready for analysis

# %%
data.pivot_table(index='date',columns='sector',values='signal1',aggfunc=np.mean)
# Out:
# sector           Fin      Tech
# date
# 2011-01-01  0.716616  0.213806
# 2011-01-02 -1.890362  0.557706
# 2011-01-03  0.212871  1.053704
# 2011-01-04 -0.782722 -0.573722
# 2011-01-05  0.671981 -0.918968
# ...              ...       ...
# 2020-12-27 -0.612833 -0.859563
# 2020-12-28  0.809741  0.015901
# 2020-12-29 -0.849997  0.276250
# 2020-12-30  0.034928  0.654204
# 2020-12-31 -0.160263 -0.678760
#
# [3653 rows x 2 columns]

# %%
data.pivot_table(index='date',columns='sector',values='signal1',aggfunc=np.max)
# Out:
# sector           Fin      Tech
# date
# 2011-01-01  1.009180  0.283229
# 2011-01-02 -1.466306  1.079511
# 2011-01-03  1.174574  1.745756
# 2011-01-04  0.261571 -0.316657
# 2011-01-05  0.893478 -0.285942
# ...              ...       ...
# 2020-12-27 -0.240506 -0.329149
# 2020-12-28  1.879978  0.486757
# 2020-12-29 -0.742333  0.644160
# 2020-12-30  0.174601  1.390706
# 2020-12-31 -0.109001 -0.678390
#
# [3653 rows x 2 columns]

# %% [markdown]
# ## Merge
# Check out documentation to learn more: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html

# %%
data2=[]
for dt in dates:
    for x in ['Tech','Fin']:
        data2.append([x,dt,np.random.randn(),np.random.randn()])
        
data2 = pd.DataFrame(data2,columns=['sector','date','signal3','signal4'])
data2
# Out:
#      sector       date   signal3   signal4
# 0      Tech 2011-01-01 -0.128021 -0.001364
# 1       Fin 2011-01-01  0.222639  0.606904
# 2      Tech 2011-01-02  1.360479  2.742521
# 3       Fin 2011-01-02 -1.920426 -1.894007
# 4      Tech 2011-01-03  0.401644 -0.436587
# ...     ...        ...       ...       ...
# 7301    Fin 2020-12-29 -0.019485  0.654231
# 7302   Tech 2020-12-30  0.594020  0.127479
# 7303    Fin 2020-12-30  0.892706 -1.403380
# 7304   Tech 2020-12-31  1.986823  1.147253
# 7305    Fin 2020-12-31 -1.244451  0.526845
#
# [7306 rows x 4 columns]

# %% [markdown]
# # Pandas Merge: Conflicts, Edge Cases, and How to Handle Them
#
# ## 🧠 Core Idea
#
# `merge()` combines datasets based on matching keys.
#
# When conflicts occur, Pandas:
# - **does not resolve them**
# - **preserves all data**
# - **forces you to decide what is correct**
#
# ---
#
# ## 🔧 Basic Example
#
#     df = data.merge(data2, on=['sector','date'])
#
# ---
#
# ## ⚠️ Edge Case 1: Conflicting Column Values
#
# ### Problem
#
# Same keys, different values:
#
# | sector | date       | signal1 |
# |--------|------------|--------|
# | Tech   | 2021-01-01 | 0.5    |
#
# | sector | date       | signal1 |
# |--------|------------|--------|
# | Tech   | 2021-01-01 | 0.9    |
#
# ---
#
# ### Result
#
# | sector | date       | signal1_x | signal1_y |
# |--------|------------|-----------|-----------|
# | Tech   | 2021-01-01 | 0.5       | 0.9       |
#
# ---
#
# ### Why This Happens
#
# - Pandas keeps both values to avoid silent data loss
# - Adds suffixes:
#   - `_x` → left DataFrame
#   - `_y` → right DataFrame
#
# ---
#
# ### How to Handle
#
# #### Choose one source:
#     df['signal1'] = df['signal1_x']
#
# #### Combine values:
#     df['signal1'] = df[['signal1_x','signal1_y']].mean(axis=1)
#
# #### Detect conflicts:
#     (df['signal1_x'] != df['signal1_y']).sum()
#
# ---
#
# ## ⚠️ Edge Case 2: Duplicate Keys (One-to-Many)
#
# ### Problem
#
# Left dataset has duplicate keys:
#
# | sector | date       | signal1 |
# |--------|------------|--------|
# | Tech   | 2021-01-01 | 0.5    |
# | Tech   | 2021-01-01 | 0.6    |
#
# ---
#
# ### Result
#
# | sector | date       | signal1 | return |
# |--------|------------|--------|--------|
# | Tech   | 2021-01-01 | 0.5    | 0.01   |
# | Tech   | 2021-01-01 | 0.6    | 0.01   |
#
# ---
#
# ### Why This Happens
#
# - One row in right dataset matches multiple rows in left dataset
#
# ---
#
# ### How to Handle
#
# #### Remove duplicates:
#     data = data.drop_duplicates(subset=['sector','date'])
#
# #### Aggregate first:
#     data = data.groupby(['sector','date']).mean().reset_index()
#
# ---
#
# ## ⚠️ Edge Case 3: Many-to-Many Merge (Data Explosion)
#
# ### Problem
#
# Duplicates exist in both datasets.
#
# Example:
# - 2 rows in left
# - 3 rows in right
#
# 👉 Result: 6 rows
#
# ---
#
# ### Why This Happens
#
# - Every matching row combines with every other matching row
#
# ---
#
# ### How to Handle
#
# #### Validate merge relationships:
#     data.merge(data2, on=['sector','date'], validate='one_to_one')
#
# Other options:
#     validate='one_to_many'
#     validate='many_to_one'
#
# ---
#
# ## ⚠️ Edge Case 4: Missing Matches
#
# ### Problem
#
# Some keys exist in one dataset but not the other.
#
# ---
#
# ### Behavior
#
# Default (`how='inner'`):
# - Drops unmatched rows
#
# ---
#
# ### How to Handle
#
# #### Keep all left data:
#     data.merge(data2, on=['sector','date'], how='left')
#
# #### Keep everything:
#     data.merge(data2, on=['sector','date'], how='outer')
#
# ---
#
# ## 🧠 Best Practices
#
# ### 1. Always check duplicates before merging
#
#     data.duplicated(['sector','date']).sum()
#
# ---
#
# ### 2. Use `validate` to enforce expectations
#
#     data.merge(data2, on=['sector','date'], validate='one_to_one')
#
# ---
#
# ### 3. Be explicit about columns
#
#     data.merge(data2[['sector','date','return']], on=['sector','date'])
#
# ---
#
# ### 4. Inspect results after merge
#
#     df.head()
#     df.shape
#
# ---
#
# ## 🧭 Mental Model
#
# `merge()` does not clean or fix data.
#
# It:
#
# > **combines datasets and exposes inconsistencies**
#
# ---
#
# ## 🔑 Final Takeaway
#
# - Conflicts are expected
# - Pandas preserves all data
# - You must define how to resolve inconsistencies
#
# ---
#
# ## 💡 One Rule to Remember
#
# > Always assume your data is messy and verify before and after every merge

# %%
data.merge(data2,left_on=['sector','date'],right_on=['sector','date'])
# Out:
#       ticker sector       date   signal1   signal2   signal3   signal4
# 0       AAPL   Tech 2011-01-01  0.283229  3.056726 -0.128021 -0.001364
# 1       MSFT   Tech 2011-01-01  0.144383  0.326354 -0.128021 -0.001364
# 2        BAC    Fin 2011-01-01  1.009180  1.956001  0.222639  0.606904
# 3         GS    Fin 2011-01-01  0.424052  1.580517  0.222639  0.606904
# 4       AAPL   Tech 2011-01-02  0.035900  1.173141  1.360479  2.742521
# ...      ...    ...        ...       ...       ...       ...       ...
# 14607     GS    Fin 2020-12-30  0.174601 -0.541720  0.892706 -1.403380
# 14608   AAPL   Tech 2020-12-31 -0.679130  0.258643  1.986823  1.147253
# 14609   MSFT   Tech 2020-12-31 -0.678390 -0.853023  1.986823  1.147253
# 14610    BAC    Fin 2020-12-31 -0.211526 -2.135673 -1.244451  0.526845
# 14611     GS    Fin 2020-12-31 -0.109001 -0.065435 -1.244451  0.526845
#
# [14612 rows x 7 columns]
